# %% [markdown]
# # Seattle Police Department Terry Stops

# %% [markdown]
# ## Problem

# %% [markdown]
# Build a classifier to predict whether an arrest was made after a Terry Stop, given information about the presence of weapons, the time of day of the call, etc. Note that this is a binary classification problem.

# %% [markdown]
# ## Setup

# %%
#Setting up environment with initial libraries needed for importing, cleaning, and initial visualization
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport
from scipy import stats

import seaborn as sns
import matplotlib.pyplot as plt
import folium
from folium.plugins import HeatMap
import sweetviz as sv

import cufflinks as cf
from datetime import datetime

import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
from statsmodels.formula.api import ols

import warnings
warnings.filterwarnings("ignore")

pd.set_option('display.max_rows', 30)
pd.set_option('display.max_columns', 25)
pd.set_option('display.float_format', '{:,}'.format)

sns.set_style('darkgrid')

# %matplotlib inline
# Out:
# C:\Users\jtang\anaconda3\envs\learn-env\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### Import the dataset

# %%
# Import Seattle Terry Stop dataset
terry_df = pd.read_csv('../data/Terry_Stops.csv')

# Verify dataset import and by calling first  five rows of data
terry_df.head()
# Out:
#   Subject Age Group  Subject ID     GO / SC Num  Terry Stop ID  \
# 0                 -          -1  20150000002351          45252
# 1                 -          -1  20150000002363          45182
# 2                 -          -1  20150000002392          45365
# 3                 -          -1  20150000002451          46430
# 4                 -          -1  20140000120677          92317
#
#   Stop Resolution Weapon Type Officer ID  Officer YOB Officer Gender  \
# 0   Field Contact        None     7591           1985              M
# 1   Field Contact        None     7591           1985              M
# 2   Field Contact        None     7560           1986              M
# 3   Field Contact        None     7591           1985              M
# 4          Arrest        None     7500           1984              M
#
#                 Officer Race Subject Perceived Race Subject Perceived Gender  \
# 0         Hispanic or Latino                  Other                   Female
# 1         Hispanic or Latino                  White                     Male
# 2                      White                  White                   Female
# 3         Hispanic or Latino                      -                        -
# 4  Black or African American                  Asian                     Male
#
#          Reported Date Reported Time Initial Call Type Final Call Type  \
# 0  2015-05-20T00:00:00      21:39:00                 -               -
# 1  2015-05-20T00:00:00      22:40:00                 -               -
# 2  2015-05-22T00:00:00      07:39:00                 -               -
# 3  2015-05-25T00:00:00      01:06:00                 -               -
# 4  2015-10-16T00:00:00      11:32:00                 -               -
#
#   Call Type                 Officer Squad Arrest Flag Frisk Flag Precinct  \
# 0         -         WEST PCT 3RD W - MARY           N          N        -
# 1         -         WEST PCT 3RD W - MARY           N          N        -
# 2         -  SOUTH PCT 1ST W - R/S RELIEF           N          N     East
# 3         -         WEST PCT 3RD W - MARY           N          N        -
# 4         -      SOUTH PCT 1ST W - ROBERT           N          N    South
#
#    Sector    Beat
# 0       -       -
# 1       -       -
# 2  E       E2
# 3       -       -
# 4  O       O2

# %%
#call shape of dataframe
terry_df.shape
# Out:
# (46315, 23)

# %% [markdown]
# >46k rows x 23 columns

# %%
terry_df.columns
# Out:
# Index(['Subject Age Group', 'Subject ID', 'GO / SC Num', 'Terry Stop ID',
#        'Stop Resolution', 'Weapon Type', 'Officer ID', 'Officer YOB',
#        'Officer Gender', 'Officer Race', 'Subject Perceived Race',
#        'Subject Perceived Gender', 'Reported Date', 'Reported Time',
#        'Initial Call Type', 'Final Call Type', 'Call Type', 'Officer Squad',
#        'Arrest Flag', 'Frisk Flag', 'Precinct', 'Sector', 'Beat'],
#       dtype='object')

# %% [markdown]
# ### Terry Stop Column Key: [Terry_Stop_Column_Key.md](data/Terry_Stop_Column_Key.md)

# %% [markdown]
# ## Data Cleaning & EDA

# %%
terry_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46315 entries, 0 to 46314
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Subject_Age_Group         46315 non-null  object
#  1   Subject_ID                46315 non-null  int64
#  2   GO_SC_Num                 46315 non-null  int64
#  3   Terry_Stop_ID             46315 non-null  int64
#  4   Stop_Resolution           46315 non-null  object
#  5   Weapon_Type               46315 non-null  object
#  6   Officer_ID                46315 non-null  object
#  7   Officer_YOB               46315 non-null  int64
#  8   Officer_Gender            46315 non-null  object
#  9   Officer_Race              46315 non-null  object
#  10  Subject_Perceived_Race    46315 non-null  object
#  11  Subject_Perceived_Gender  46315 non-null  object
#  12  Reported_Date             46315 non-null  object
#  13  Reported_Time             46315 non-null  object
#  14  Initial_Call_Type         46315 non-null  object
#  15  Final_Call_Type           46315 non-null  object
#  16  Call_Type                 46315 non-null  object
#  17  Officer_Squad             45710 non-null  object
#  18  Arrest_Flag               46315 non-null  object
#  19  Frisk_Flag                46315 non-null  object
#  20  Precinct                  46315 non-null  object
#  21  Sector                    46315 non-null  object
#  22  Beat                      46315 non-null  object
# dtypes: int64(4), object(19)
# memory usage: 8.1+ MB

# %% [markdown]
# #### [X] Replace spaces from column names

# %%
terry_df.columns = ['Subject_Age_Group', 'Subject_ID', 'GO_SC_Num', 'Terry_Stop_ID',
       'Stop_Resolution', 'Weapon_Type', 'Officer_ID', 'Officer_YOB',
       'Officer_Gender', 'Officer_Race', 'Subject_Perceived_Race',
       'Subject_Perceived_Gender', 'Reported_Date', 'Reported_Time',
       'Initial_Call_Type', 'Final_Call_Type', 'Call_Type', 'Officer_Squad',
       'Arrest_Flag', 'Frisk_Flag', 'Precinct', 'Sector', 'Beat']
terry_df.columns
# Out:
# Index(['Subject_Age_Group', 'Subject_ID', 'GO_SC_Num', 'Terry_Stop_ID',
#        'Stop_Resolution', 'Weapon_Type', 'Officer_ID', 'Officer_YOB',
#        'Officer_Gender', 'Officer_Race', 'Subject_Perceived_Race',
#        'Subject_Perceived_Gender', 'Reported_Date', 'Reported_Time',
#        'Initial_Call_Type', 'Final_Call_Type', 'Call_Type', 'Officer_Squad',
#        'Arrest_Flag', 'Frisk_Flag', 'Precinct', 'Sector', 'Beat'],
#       dtype='object')

# %%
terry_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46315 entries, 0 to 46314
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Subject_Age_Group         46315 non-null  object
#  1   Subject_ID                46315 non-null  int64
#  2   GO_SC_Num                 46315 non-null  int64
#  3   Terry_Stop_ID             46315 non-null  int64
#  4   Stop_Resolution           46315 non-null  object
#  5   Weapon_Type               46315 non-null  object
#  6   Officer_ID                46315 non-null  object
#  7   Officer_YOB               46315 non-null  int64
#  8   Officer_Gender            46315 non-null  object
#  9   Officer_Race              46315 non-null  object
#  10  Subject_Perceived_Race    46315 non-null  object
#  11  Subject_Perceived_Gender  46315 non-null  object
#  12  Reported_Date             46315 non-null  object
#  13  Reported_Time             46315 non-null  object
#  14  Initial_Call_Type         46315 non-null  object
#  15  Final_Call_Type           46315 non-null  object
#  16  Call_Type                 46315 non-null  object
#  17  Officer_Squad             45710 non-null  object
#  18  Arrest_Flag               46315 non-null  object
#  19  Frisk_Flag                46315 non-null  object
#  20  Precinct                  46315 non-null  object
#  21  Sector                    46315 non-null  object
#  22  Beat                      46315 non-null  object
# dtypes: int64(4), object(19)
# memory usage: 8.1+ MB

# %%
terry_df.isnull().any()
# Out:
# Subject_Age_Group           False
# Subject_ID                  False
# GO_SC_Num                   False
# Terry_Stop_ID               False
# Stop_Resolution             False
# Weapon_Type                 False
# Officer_ID                  False
# Officer_YOB                 False
# Officer_Gender              False
# Officer_Race                False
# Subject_Perceived_Race      False
# Subject_Perceived_Gender    False
# Reported_Date               False
# Reported_Time               False
# Initial_Call_Type           False
# Final_Call_Type             False
# Call_Type                   False
# Officer_Squad                True
# Arrest_Flag                 False
# Frisk_Flag                  False
# Precinct                    False
# Sector                      False
# Beat                        False
# dtype: bool

# %% [markdown]
# ### Checking for missing values

# %%
#confirming missing values with a for loop
for col in terry_df:
    mv = terry_df[col].isna().sum()
    if mv > 0:
        print(f'{col} column has {mv} missing values')
# Out:
# Officer_Squad column has 605 missing values

# %% [markdown]
# #### [ ] Drop missing values in 'Officer Squad'

# %% [markdown]
# ### Check for duplicate rows

# %%
#checking for duplicate rows across all columns
duplicate_rows = terry_df[terry_df.duplicated()]
print(f"The are {len(duplicate_rows)} duplicate rows in the dataframe.")
# Out:
# The are 0 duplicate rows in the dataframe.

# %% [markdown]
# ### Initial visualization libraries for EDA

# %% [markdown]
# #### Link to initial Pandas Profiling Report: [terry_pandasprofile_base.html](files/terry_pandasprofile_base.html)

# %% [markdown]
# #### Link to initial Sweet Viz report [terry_sweetviz_base.html](files/terry_sweetviz_base.html)

# %% [markdown]
# ### Looking at column values

# %%
for col in terry_df.columns:
    print(col)
    print(terry_df[col].value_counts())
    print('\n')
# Out:
# Subject_Age_Group
# 26_-_35         15403
# 36_-_45          9775
# 18_-_25          9336
# 46_-_55          5992
# 56_and_Above     2348
# 1_-_17           1961
# -                1500
# Name: Subject_Age_Group, dtype: int64
#
#
# Subject_ID
# -1              34744
#  7726859935        19
#  7753260438        18
#  7727117712        13
#  12162542666       11
#                 ...
#  7728036059         1
#  7728382188         1
#  7728607474         1
#  7725672697         1
#  16219707395        1
# Name: Subject_ID, Length: 8658, dtype: int64
#
#
# GO_SC_Num
# 20160000378750    16
# 20150000190790    16
# 20180000134604    14
# 20190000441736    13
# 20170000132836    13
#                   ..
# 20160000174160     1
# 20170000156685     1
# 20200000272466     1
# 20180000001810     1
# 20180000071981     1
# Name: GO_SC_Num, Length: 36265, dtype: int64
#
#
# Terry_Stop_ID
# 19268585233    3
# 13080077761    3
# 15045077325    3
# 19324329995    3
# 15595812669    2
#               ..
# 383630         1
# 49805          1
# 389771         1
# 71190          1
# 131072         1
# Name: Terry_Stop_ID, Length: 46279, dtype: int64
#
#
# Stop_Resolution
# Field Contact               18560
# Offense Report              15452
# Arrest                      11398
# Referred for Prosecution      728
# Citation / Infraction         177
# Name: Stop_Resolution, dtype: int64
#
#
# Weapon_Type
# None                                    32565
# -                                       11034
# Lethal Cutting Instrument                1482
# Knife/Cutting/Stabbing Instrument         577
# Handgun                                   284
# Firearm Other                             100
# Blunt Object/Striking Implement            77
# Club, Blackjack, Brass Knuckles            49
# Firearm                                    36
# Mace/Pepper Spray                          27
# Other Firearm                              22
# Firearm (unk type)                         15
# Taser/Stun Gun                             10
# Club                                        9
# Rifle                                       7
# None/Not Applicable                         7
# Fire/Incendiary Device                      6
# Shotgun                                     3
# Automatic Handgun                           2
# Brass Knuckles                              1
# Blackjack                                   1
# Personal Weapons (hands, feet, etc.)        1
# Name: Weapon_Type, dtype: int64
#
#
# Officer_ID
# 7456      417
# 7634      341
# 7773      321
# 7765      315
# 7758      308
#          ...
# 4311        1
# 7558        1
# 5786        1
# 6049        1
# 8699        1
# Name: Officer_ID, Length: 1201, dtype: int64
#
#
# Officer_YOB
# 1986    3239
# 1987    2961
# 1984    2722
# 1991    2660
# 1985    2481
#         ...
# 1948      11
# 1952       9
# 1949       5
# 1946       2
# 1951       1
# Name: Officer_YOB, Length: 52, dtype: int64
#
#
# Officer_Gender
# M    40991
# F     5295
# N       29
# Name: Officer_Gender, dtype: int64
#
#
# Officer_Race
# White                            35083
# Hispanic or Latino                2653
# Two or More Races                 2592
# Asian                             1972
# Black or African American         1832
# Not Specified                     1348
# Nat Hawaiian/Oth Pac Islander      447
# American Indian/Alaska Native      317
# Unknown                             71
# Name: Officer_Race, dtype: int64
#
#
# Subject_Perceived_Race
# White                                        22601
# Black or African American                    13784
# Unknown                                       2526
# -                                             1886
# Hispanic                                      1684
# Asian                                         1491
# American Indian or Alaska Native              1334
# Multi-Racial                                   809
# Other                                          152
# Native Hawaiian or Other Pacific Islander       48
# Name: Subject_Perceived_Race, dtype: int64
#
#
# Subject_Perceived_Gender
# Male                                                         36260
# Female                                                        9429
# Unable to Determine                                            326
# -                                                              274
# Unknown                                                         22
# Gender Diverse (gender non-conforming and/or transgender)        4
# Name: Subject_Perceived_Gender, dtype: int64
#
#
# Reported_Date
# 2015-10-01T00:00:00    101
# 2015-09-29T00:00:00     66
# 2015-05-28T00:00:00     57
# 2015-07-18T00:00:00     55
# 2019-04-26T00:00:00     54
#                       ...
# 2015-03-15T00:00:00      1
# 2015-04-14T00:00:00      1
# 2015-05-13T00:00:00      1
# 2015-05-06T00:00:00      1
# 2015-05-10T00:00:00      1
# Name: Reported_Date, Length: 2163, dtype: int64
#
#
# Reported_Time
# 19:18:00    51
# 02:56:00    51
# 17:00:00    51
# 03:09:00    50
# 03:13:00    50
#             ..
# 19:35:10     1
# 19:26:09     1
# 13:03:52     1
# 09:40:42     1
# 11:12:37     1
# Name: Reported_Time, Length: 12218, dtype: int64
#
#
# Initial_Call_Type
# -                                                 13113
# SUSPICIOUS STOP - OFFICER INITIATED ONVIEW         3102
# SUSPICIOUS PERSON, VEHICLE OR INCIDENT             2923
# DISTURBANCE, MISCELLANEOUS/OTHER                   2382
# ASLT - IP/JO - WITH OR W/O WPNS (NO SHOOTINGS)     1952
#                                                   ...
# TRACKING ALARM                                        1
# KNOWN KIDNAPPNG                                       1
# HARBOR - WATER EMERGENCIES                            1
# DEMONSTRATIONS                                        1
# ALARM - RESIDENTIAL - SILENT/AUD PANIC/DURESS         1
# Name: Initial_Call_Type, Length: 167, dtype: int64
#
#
# Final_Call_Type
# -                                                    13113
# --SUSPICIOUS CIRCUM. - SUSPICIOUS PERSON              3670
# --PROWLER - TRESPASS                                  3275
# --DISTURBANCE - OTHER                                 2660
# --ASSAULTS, OTHER                                     2244
#                                                      ...
# OVERDOSE - DRUG RELATED CASUALTY                         1
# PEACE-STANDBY TO ASSURE (NO COURT ORDR SVC)              1
# --CROWD MGMNT (STAND BY ONLY)                            1
# --COMMERCIAL SEXUAL EXPLOITATION OF MINORS (CSEC)        1
# -OFF DUTY EMPLOYMENT                                     1
# Name: Final_Call_Type, Length: 205, dtype: int64
#
#
# Call_Type
# 911                              20734
# -                                13113
# ONVIEW                            8910
# TELEPHONE OTHER, NOT 911          3232
# ALARM CALL (NOT POLICE ALARM)      318
# TEXT MESSAGE                         7
# SCHEDULED EVENT (RECURRING)          1
# Name: Call_Type, dtype: int64
#
#
# Officer_Squad
# TRAINING - FIELD TRAINING SQUAD                 4957
# WEST PCT 1ST W - DAVID/MARY                     1526
# WEST PCT 2ND W - D/M RELIEF                     1003
# SOUTHWEST PCT 2ND W - FRANK                      944
# NORTH PCT 2ND WATCH - NORTH BEATS                885
#                                                 ...
# RECORDS - DAY SHIFT                                1
# COMMUNITY OUTREACH - SPECIAL PROJECTS DETAIL       1
# TRAINING - LEARNING MANAGEMENT SYSTEM              1
# BURG/THEFT/JUV - WEST                              1
# TRAINING - ADVANCED - SQUAD C                      1
# Name: Officer_Squad, Length: 170, dtype: int64
#
#
# Arrest_Flag
# N    43125
# Y     3190
# Name: Arrest_Flag, dtype: int64
#
#
# Frisk_Flag
# N    35488
# Y    10349
# -      478
# Name: Frisk_Flag, dtype: int64
#
#
# Precinct
# West         11121
# North        10184
# -             9811
# East          6111
# South         5551
# Southwest     2320
# SouthWest      966
# Unknown        200
# OOJ             32
# FK ERROR        19
# Name: Precinct, dtype: int64
#
#
# Sector
# -         10015
# E          2337
# M          2270
# N          2191
# K          1762
#           ...
# W           385
# J           369
# L           357
# C           349
# 99           53
# Name: Sector, Length: 36, dtype: int64
#
#
# Beat
# -         9956
# N3        1175
# E2        1092
# K3         909
# M2         852
#           ...
# N1          71
# 99          53
# 99          31
# OOJ         22
# S            2
# Name: Beat, Length: 107, dtype: int64

# %%
#check all unique values within each column
for col in terry_df.columns:
    print(col)
    print(terry_df[col].unique())
    print('\n')
# Out:
# Subject_Age_Group
# ['-' '1_-_17' '18_-_25' '26_-_35' '36_-_45' '46_-_55' '56_and_Above']
#
#
# Subject_ID
# [         -1  7726713382  7727213211 ... 20356430687 20370055391
#  20414308762]
#
#
# GO_SC_Num
# [20150000002351 20150000002363 20150000002392 ... 20210000022390
#  20210000027381 20210000033131]
#
#
# Terry_Stop_ID
# [      45252       45182       45365 ... 20356441466 20370213152
#  20414094359]
#
#
# Stop_Resolution
# ['Field Contact' 'Arrest' 'Citation / Infraction' 'Offense Report'
#  'Referred for Prosecution']
#
#
# Weapon_Type
# ['None' 'Firearm Other' 'Lethal Cutting Instrument' 'Handgun' '-'
#  'Club, Blackjack, Brass Knuckles' 'Knife/Cutting/Stabbing Instrument'
#  'Other Firearm' 'Rifle' 'Fire/Incendiary Device'
#  'Blunt Object/Striking Implement' 'Firearm (unk type)'
#  'Mace/Pepper Spray' 'None/Not Applicable' 'Club' 'Firearm'
#  'Taser/Stun Gun' 'Shotgun' 'Brass Knuckles' 'Automatic Handgun'
#  'Blackjack' 'Personal Weapons (hands, feet, etc.)']
#
#
# Officer_ID
# ['7591  ' '7560  ' '7500  ' ... '8786  ' '6983  ' '5917  ']
#
#
# Officer_YOB
# [1985 1986 1984 1965 1961 1963 1977 1973 1964 1959 1979 1981 1969 1983
#  1966 1968 1987 1952 1970 1976 1972 1982 1991 1988 1971 1978 1990 1975
#  1967 1992 1962 1980 1948 1989 1953 1974 1960 1958 1994 1993 1996 1900
#  1995 1997 1957 1955 1954 1956 1946 1949 1998 1951]
#
#
# Officer_Gender
# ['M' 'F' 'N']
#
#
# Officer_Race
# ['Hispanic or Latino' 'White' 'Black or African American' 'Asian'
#  'American Indian/Alaska Native' 'Two or More Races' 'Not Specified'
#  'Nat Hawaiian/Oth Pac Islander' 'Unknown']
#
#
# Subject_Perceived_Race
# ['Other' 'White' '-' 'Asian' 'Black or African American' 'Unknown'
#  'American Indian or Alaska Native' 'Hispanic' 'Multi-Racial'
#  'Native Hawaiian or Other Pacific Islander']
#
#
# Subject_Perceived_Gender
# ['Female' 'Male' '-' 'Unable to Determine' 'Unknown'
#  'Gender Diverse (gender non-conforming and/or transgender)']
#
#
# Reported_Date
# ['2015-05-20T00:00:00' '2015-05-22T00:00:00' '2015-05-25T00:00:00' ...
#  '2015-03-31T00:00:00' '2015-05-13T00:00:00' '2015-04-14T00:00:00']
#
#
# Reported_Time
# ['21:39:00' '22:40:00' '07:39:00' ... '23:32:26' '13:47:49' '10:35:06']
#
#
# Initial_Call_Type
# ['-' 'DIST - IP/JO - DV DIST - NO ASLT'
#  'THEFT (DOES NOT INCLUDE SHOPLIFT OR SVCS)'
#  'DISTURBANCE, MISCELLANEOUS/OTHER'
#  'SUSPICIOUS PERSON, VEHICLE OR INCIDENT'
#  'SUSPICIOUS STOP - OFFICER INITIATED ONVIEW'
#  'SHOTS - IP/JO - INCLUDES HEARD/NO ASSAULT' 'SHOPLIFT - THEFT'
#  'NARCOTICS - VIOLATIONS (LOITER, USE, SELL, NARS)'
#  'MVC - HIT AND RUN (NON INJURY), INCLUDES IP/JO'
#  'ASLT - IP/JO - WITH OR W/O WPNS (NO SHOOTINGS)' 'TRESPASS'
#  'MVC - WITH INJURIES (INCLUDES HIT AND RUN)'
#  'FIGHT - VERBAL/ORAL (NO WEAPONS)'
#  'WEAPN-IP/JO-GUN,DEADLY WPN (NO THRT/ASLT/DIST)' 'AUTO RECOVERY'
#  'PROWLER - IP/JO' 'PERSON IN BEHAVIORAL/EMOTIONAL CRISIS'
#  'FIGHT - IP - PHYSICAL (NO WEAPONS)'
#  'BURG - IP/JO - RES (INCL UNOCC STRUCTURES)'
#  'TRAFFIC STOP - OFFICER INITIATED ONVIEW' 'NUISANCE - MISCHIEF'
#  'HAZ - POTENTIAL THRT TO PHYS SAFETY (NO HAZMAT)'
#  'WARRANT - MISD WARRANT PICKUP' 'ROBBERY - IP/JO (INCLUDES STRONG ARM)'
#  'BURG - RES (INCL UNOCC STRUCTURES ON PROP)'
#  'UNKNOWN - ANI/ALI - LANDLINE (INCLUDES OPEN LINE)'
#  'SHOTS -DELAY/INCLUDES HEARD/NO ASSAULT'
#  'ASLT - WITH OR W/O WEAPONS (NO SHOOTINGS)'
#  'ALARM - COMM, SILENT/AUD BURG (INCL BANKS)'
#  'CARJACKING - IP/JO - ROBBERY'
#  'UNKNOWN - ANI/ALI - WRLS PHNS (INCL OPEN LINE)'
#  'DOWN - CHECK FOR PERSON DOWN' 'TRAFFIC - ROAD RAGE'
#  'BURG - COMM BURGLARY (INCLUDES SCHOOLS)'
#  'THREATS (INCLS IN-PERSON/BY PHONE/IN WRITING)' 'WARRANT - FELONY PICKUP'
#  'DIST - DV - NO ASLT' 'AUTO THEFT - VEH THEFT OR THEFT & RECOVERY'
#  'SICK PERSON' 'PROPERTY - DAMAGE' 'ASLT - IP/JO - DV' 'ARSON - IP/JO'
#  'ORDER - IP - VIOLATION OF DV COURT ORDER'
#  'ROBBERY (INCLUDES STRONG ARM)'
#  'SEX IN PUBLIC PLACE/VIEW (INCL MASTURBATION)'
#  'ORDER - VIOLATING DV COURT ORDER'
#  'ORDER - VIOLATION OF COURT ORDER (NON DV)'
#  'BURG - IP/JO - COMM BURG (INCLUDES SCHOOLS)'
#  'TRAFFIC - BLOCKING ROADWAY'
#  'UNDERCOVER OPS, CAUTION (INCLUDES STAKEOUTS)'
#  'ASLT - IP/JO - PERSON SHOT OR SHOT AT' 'PANHANDLING, AGGRESSIVE'
#  'FOLLOW UP' 'DUI - DRIVING UNDER INFLUENCE'
#  'FIGHT - IP/JO - WITH WEAPONS' 'FIGHT - WITH WEAPONS'
#  'FIGHT - JO - PHYSICAL (NO WEAPONS)' 'LEWD -  (EXPOSING, FLASHING)'
#  'PROPERTY - DAMAGE (GUN RELATED)' 'TRAFFIC - MOVING VIOLATION'
#  'MVC - UNK INJURIES' 'SFD - ASSIST ON FIRE OR MEDIC RESPONSE'
#  'PREMISE CHECK, OFFICER INITIATED ONVIEW ONLY'
#  'ASSIST OTHER AGENCY - ROUTINE SERVICE'
#  'HARAS - NO BIAS, THREATS OR MALICIOUSNESS' 'ILLEGAL DUMPING'
#  'LIQUOR VIOLATIONS - ADULT' 'FIREWORKS - NUISANCE (NO HAZARD)'
#  'UNKNOWN - COMPLAINT OF UNKNOWN NATURE'
#  'FRAUD - FORGERY,BUNCO, SCAMS, ID THEFT, ETC'
#  'PROPERTY - FOUND GUN, SHELLCASINGS'
#  'WEAPN - GUN,DEADLY WPN (NO THRTS/ASLT/DIST)'
#  'SUICIDE - IP/JO SUICIDAL PERSON AND ATTEMPTS'
#  'DOA - CASUALTY, DEAD BODY' 'OPEN - BUILDING, DOOR, ETC.'
#  'NARCOTICS WARRANT SERVICE' 'MVC - NON INJURY, BLOCKING'
#  'HELP THE OFFICER' 'VICE - PROSTITUTION' 'SERVICE - WELFARE CHECK'
#  'THEFT OF SERVICES' 'AUTO THEFT-IP/JO - VEHICLE, PLATES, TABS'
#  'NOISE - DISTURBANCE (PARTY, ETC)' 'LIQUOR VIOLATIONS - MINOR'
#  'PURSE SNATCH - IP/JO - ROBBERY' 'RAPE - IP/JO'
#  'OVERDOSE - DRUG RELATED CASUALTY' 'PROWLER' 'JUVENILE - RUNAWAY'
#  'PURSE SNATCH - ROBBERY' 'JUVENILE - RUNAWAY PICKUP' 'MISSING - CHILD'
#  'NARCOTICS WARRANT SERVICE - EXECUTED, SECURED' 'ASLT - DV'
#  'WARRANT - SEARCH. CAUTION (EXCL NARCOTICS)' 'TRAF - ELUDING POLICE'
#  'FOOT - ELUDING POLICE' 'CHILD - IP/JO - LURING'
#  'WARRANT - SEARCH. EXECUTED, SECURED' 'CARJACKING - ROBBERY'
#  'THREATS - DV - NO ASSAULT' 'RAPE' 'ASLT - PERSON SHOT OR SHOT AT'
#  'ASSIST PUBLIC - NO WELFARE CHK OR DV ORDER SERVICE'
#  'CHILD - ABAND, ABUSED, MOLESTED, NEGLECTED'
#  'ORDER  - SERVICE OF DV COURT ORDER' 'OFF DUTY EMPLOYMENT'
#  'NOISE - DIST, GENERAL (CONST, RESID, BALL PLAY)'
#  'ASLT - MOLESTED ADULT (GROPED, FONDLED, ETC.)' 'DEMONSTRATIONS'
#  'PARKS VIOLATIONS/CITES (INCLUDES EXCLUSIONS)'
#  '-ASSIGNED DUTY - FOOT BEAT (FROM ASSIGNED CAR)'
#  'TRAFFIC - ASSIST MOTORIST'
#  'CHILD - IP/JO - ABAND, ABUSE, MOLEST, NEGLECT'
#  '-ASSIGNED DUTY - STAKEOUT'
#  'ALARM - RESIDENTIAL - BURGLARY, SILENT/AUDIBLE'
#  'PEACE-STANDBY TO ASSURE (NO COURT ORDR SVC)'
#  'MVC - REPORT, NON INJ/NON BLKG OR AFTER FACT INJ' 'EXPLOSION - IP/JO'
#  'BURN - RECKLESS BURNING' 'TRU - THEFT'
#  'ASSIST OTHER AGENCY - EMERGENCY SERVICE' 'BOMB THREATS - IP/JO'
#  'PARKING VIOLATION (EXCEPT ABANDONED CAR)' 'ARSON - REPORT'
#  'BIAS -RACIAL, POLITICAL, SEXUAL MOTIVATION' 'PEDESTRIAN VIOLATIONS'
#  'AWOL - ADULT OR JUVENILE' 'ASSIST SPD - ROUTINE SERVICE'
#  'DIRECTED PATROL ACTIVITY'
#  'ALARM - AUDIBLE AUTOMOBILE (UNOCC/ANTI-THEFT)'
#  'DOWN - CHECK FOR DOWN PERSON' 'LITTERING' 'ALARM - BANK (HOLD-UP)'
#  'PROPERTY - FOUND' 'CHILD -  LURING' 'NARCOTICS - FOUND' 'FOUND - PERSON'
#  'AUTO - THEFT/LOSS, PLATES AND/OR TAB' 'SUSPICIOUS PACKAGE'
#  'ANIMAL - INJURED, DEAD HAZARD, OTHER'
#  'SUICIDE, SUICIDAL PERSON AND ATTEMPTS' 'REQUEST TO WATCH'
#  'KNOWN KIDNAPPNG' 'ESCAPE - PRISONER' 'MISSING - ADULT'
#  'SLEEPER ABOARD BUS/COMMUTER TRAIN'
#  'PHONE - OBSCENE OR NUISANCE PHONE CALLS'
#  'ALARM - ATM MACHINE, FREE STANDING'
#  'ALARM - RESIDENTIAL - SILENT/AUD PANIC/DURESS' 'VICE - PORNOGRAPHY'
#  'GAMBLING' 'URINATING, DEFECATING IN PUBLIC'
#  'HAZ - IMMINENT THRT TO PHYS SAFETY (NO HAZ MAT)'
#  'HARBOR - WATER EMERGENCIES'
#  'INJURED - IP/JO - PERSON/INDUSTRIAL ACCIDENT' 'ANIMAL - IP/JO - BITE'
#  'UNKNOWN - ANI/ALI - PAY PHNS (INCL OPEN LINE)'
#  'MISSING - (ALZHEIMER, ENDANGERED, ELDERLY)'
#  'ORDER - ASSIST DV VIC W/SRVC OF COURT ORDER'
#  'INJURED -  PERSON/INDUSTRIAL ACCIDENT' 'TRACKING ALARM'
#  'ALARM - COMM, HOLD-UP/PANIC (EXCEPT BANKS)'
#  'WARRANT PICKUP - FROM OTHER AGENCY' 'ASSIST SPD - URGENT SERVICE'
#  'ANIMAL, REPORT - BITE']
#
#
# Final_Call_Type
# ['-' '--DV - ARGUMENTS, DISTURBANCE (NO ARREST)' '--THEFT - CAR PROWL'
#  '--SUSPICIOUS CIRCUM. - SUSPICIOUS PERSON'
#  '--SEX OFFENSES (NON-RAPE) - LEWD CONDUCT' '--PROWLER - TRESPASS'
#  '--WEAPON, PERSON WITH - GUN' '--THEFT - SHOPLIFT' '--NARCOTICS - OTHER'
#  '--TRAFFIC - MV COLLISION INVESTIGATION'
#  '--DV - DOMESTIC VIOL/ASLT (ARREST MANDATORY)'
#  '--SUSPICIOUS CIRCUM. - SUSPICIOUS VEHICLE' '--ASSAULTS, OTHER'
#  '--DISTURBANCE - OTHER' '--THEFT - AUTO ACCESSORIES'
#  '--PROPERTY DEST (DAMG)' '--KIDNAP - GENERAL'
#  '--AUTOMOBILES - RECOVERY (THEFT)' '--WARRANT SERVICES - FELONY'
#  '--THEFT - BICYCLE' '--TRAFFIC - MOVING VIOLATION'
#  '--WEAPON,PERSON WITH - OTHER WEAPON' '--ASSAULTS - HARASSMENT, THREATS'
#  'NUISANCE - MISCHIEF' '--WARRANT SERVICES - MISDEMEANOR'
#  '--ROBBERY - STRONG ARM' '--THEFT - ALL OTHER'
#  '--SUSPICIOUS CIRCUM. - BUILDING (OPEN DOOR, ETC)' '--ROBBERY - ARMED'
#  '--CRISIS COMPLAINT - GENERAL'
#  '--ALARM-COMM (INC BANK, ATM, SCHOOLS, BSN)' '--DISTURBANCE - FIGHT'
#  '--BURGLARY - RESIDENTIAL OCCUPIED'
#  '--AUTOMOBILES - AUTO THEFT & RECOVERY'
#  '--BURGLARY - NON RESIDENTIAL/COMMERCIAL' '--PERSON - RUNAWAY' 'TRESPASS'
#  'ROBBERY - IP/JO (INCLUDES STRONG ARM)'
#  'SUSPICIOUS PERSON, VEHICLE OR INCIDENT' '--PROWLER - GENERAL'
#  '--NARCOTICS - MARIJUANA PUBLIC USE(NOT DISPENSARY)'
#  '--ARSON, BOMBS, EXPLO - RECKLESS BURNING'
#  '--BURGLARY - RESIDENTIAL, UNOCCUPIED'
#  '--DV - ENFORCE COURT ORDER (ARREST MANDATED)'
#  '--AUTOMOBILES - AUTO THEFT' '--TRAFFIC - D.U.I.'
#  '-ASSIGNED DUTY - STAKEOUT' '--ASSAULTS - FIREARM INVOLVED'
#  '--DRIVE BY SHOOTING - NO INJURIES'
#  '--PROPERTY DEST (DAMG) - GRAFFITI (INCLUDES GANG)'
#  '--VICE - PROSTITUTION' '--ANIMAL COMPLAINT - NOISE,STRAY,BITE'
#  '--ASSIST OTHER AGENCY - COUNTY AGENCY' '--NARCOTICS - NARS REPORT'
#  'PROPERTY - DAMAGE' '--DV - ASSIST VICTIM BY COURT ORDER'
#  '--FRAUD - FRAUD, INCLUDING BUNCO' '--TRAFFIC - REFUSE TO STOP (PURSUIT)'
#  'DISTURBANCE, MISCELLANEOUS/OTHER'
#  '--BURGLARY - UNOCC STRUC ON RESN PROP'
#  'PERSON IN BEHAVIORAL/EMOTIONAL CRISIS'
#  '--NARCOTICS - DRUG TRAFFIC LOITERING'
#  'FIGHT - JO - PHYSICAL (NO WEAPONS)'
#  '--PROWLER - TRESPASS, PARKS EXCLUSION'
#  'THREATS (INCLS IN-PERSON/BY PHONE/IN WRITING)'
#  '--MISCHIEF OR NUISANCE - GENERAL'
#  '--NARCOTICS - NARCOTICS WARRANT SERVICE'
#  '--INTOX & LIQ VIOLS - ADULTS (VIOLATIONS)' '--DISTURBANCE - NOISE'
#  '--ASSIST OTHER AGENCY - CITY AGENCY'
#  '--PREMISE CHECKS - CRIME PREVENTION' '--FRAUD - FORGERY, BAD CHECKS'
#  'SHOPLIFT - THEFT' '--MISC MISD AND VIOLS - RECKLESS ENDANGERMENT'
#  'ASSIST OTHER AGENCY - ROUTINE SERVICE' '--PROPERTY - FOUND PROPERTY'
#  'FIGHT - IP/JO - WITH WEAPONS' 'FIGHT - IP - PHYSICAL (NO WEAPONS)'
#  '--CASUALTY,NON-TRAF,NON-CRIM - NON-DRUG RELATED' '--HAZARDS - HAZARDS'
#  '--ASSIST OTHER AGENCY - STATE AGENCY'
#  '--DV - DOMESTIC VIOLENCE (ARREST DISCRETIONARY)'
#  '--NARCOTICS - FOUND , RECOVERED NARCOTICS'
#  'BURG - IP/JO - RES (INCL UNOCC STRUCTURES)'
#  '--ASSIST PUBLIC - OTHER (NON-SPECIFIED)' '--DISTURBANCE - JUVENILE'
#  '--PERSON - FOUND PERSON' 'SUSPICIOUS STOP - OFFICER INITIATED ONVIEW'
#  '--RAPE - KNOWN SUSPECT (ACQUAINTANCE)'
#  '--CASUALTY NON-TRAF NON-CRIM - DRUG RELATED (OD)'
#  '--INTOX & LIQ VIOLS - MINORS (VIOLATIONS)' '--PERSON - MISSING PERSON'
#  '--CHILD - CHILD ENDANGERMENT' '--HARBOR - ASSIST BOATER (NON EMERG)'
#  '-PRISONER ESCORT - BUSY CODE' 'PURSE SNATCH - IP/JO - ROBBERY'
#  'WARRANT - FELONY PICKUP' 'BURG - COMM BURGLARY (INCLUDES SCHOOLS)'
#  '--RAPE - UNKNOWN SUSPECT (STRANGER)'
#  '--ARSON,BOMBS,EXPLO - BOMBS, EXPLO,LARGE FIREWORKS'
#  'SHOTS -DELAY/INCLUDES HEARD/NO ASSAULT'
#  'BURG - IP/JO - COMM BURG (INCLUDES SCHOOLS)' '--HOMICIDE'
#  'HAZ - POTENTIAL THRT TO PHYS SAFETY (NO HAZMAT)'
#  '--TRAFFIC - PEDESTRIAN VIOLATION'
#  '--COMMERCIAL SEXUAL EXPLOITATION OF MINORS (CSEC)'
#  '--DV - SERVICE OF COURT ORDER'
#  '-ASSIGNED DUTY - COMMUNITY,SCHOOL,SPECIAL EVENT'
#  '--DV - STANDBY TO ASSURE PEACE' '--DISTURBANCE - NOISE RESIDENTIAL'
#  '--TRAFFIC - ASSIST MOTORIST' '--SEX OFFENSES (RAPE) - MOLESTING'
#  '--MISC MISD AND VIOLS - PARKS EXCLUSION'
#  'WEAPN - GUN,DEADLY WPN (NO THRTS/ASLT/DIST)'
#  '--ARSON, BOMBS, EXPLO - ARSON'
#  'ASLT - WITH OR W/O WEAPONS (NO SHOOTINGS)'
#  '--DV - DOMESTIC THREATS BY PHONE OR WRITING'
#  '--CHILD - ABANDONED, ABUSED AND NEGLECTED' 'ASLT - DV'
#  '--TRAFFIC - BLOCKING TRAFFIC'
#  'THEFT (DOES NOT INCLUDE SHOPLIFT OR SVCS)'
#  '--TRAFFIC - PARKING VIOL (EXCEPT ABANDONED CAR)'
#  '--INTOX & LIQ VIOLS - INTOXICATED PERSON'
#  'ASLT - IP/JO - WITH OR W/O WPNS (NO SHOOTINGS)'
#  '--AUTOMOBILES - LICENSE PLATE(S) THEFT OR LOSS'
#  'UNKNOWN - COMPLAINT OF UNKNOWN NATURE' '--ASSAULTS - GANG RELATED'
#  'NARCOTICS - VIOLATIONS (LOITER, USE, SELL, NARS)'
#  '--HARBOR - BOAT ACCIDENT' 'WARRANT - MISD WARRANT PICKUP'
#  '--ALARM-RESIDENTIAL BURG' 'FOLLOW UP'
#  'BURG - RES (INCL UNOCC STRUCTURES ON PROP)' 'MVC - NON INJURY, BLOCKING'
#  'ASLT - IP/JO - DV' '--TRAFFIC - BICYCLE VIOLATION'
#  'FIREWORKS - NUISANCE (NO HAZARD)'
#  'SHOTS - IP/JO - INCLUDES HEARD/NO ASSAULT'
#  'PREMISE CHECK, OFFICER INITIATED ONVIEW ONLY' 'AUTO RECOVERY'
#  'ASLT - IP/JO - PERSON SHOT OR SHOT AT'
#  'AUTO THEFT - VEH THEFT OR THEFT & RECOVERY'
#  'SFD - ASSIST ON FIRE OR MEDIC RESPONSE'
#  'WEAPN-IP/JO-GUN,DEADLY WPN (NO THRT/ASLT/DIST)'
#  'HOSPITAL GUARD ASSIGNMENT' 'HARAS - NO BIAS, THREATS OR MALICIOUSNESS'
#  '--ALARM-COMM ROBB (BANK, PANIC, DURESS)' 'TRAFFIC - BLOCKING ROADWAY'
#  'MVC - WITH INJURIES (INCLUDES HIT AND RUN)' 'BOMB - THREATS'
#  '--VICE - OTHER' 'DOWN - CHECK FOR PERSON DOWN'
#  '--CROWD MGMNT (STAND BY ONLY)' '--ASSIST OTHER AGENCY - FEDERAL AGENCY'
#  '--SEX OFFENSES (NON-RAPE) - FAILURE TO REGISTER'
#  '--ALARM-OTHER (VARDA,PDT,FIRE,LOCAL,METRO,ETC))'
#  '--ANIMAL COMPLAINT - INJURED,DEAD,DANGEROUS' 'THEFT OF SERVICES'
#  'LIQUOR VIOLATIONS - ADULT' 'SERVICE - WELFARE CHECK'
#  '--ASSAULTS - TELEPHONE, WRITING'
#  '--CRISIS COMPLAINT - PICK-UP OR TRANSPORT'
#  'ORDER - VIOLATION OF COURT ORDER (NON DV)'
#  'ROBBERY (INCLUDES STRONG ARM)' '-OFF DUTY EMPLOYMENT'
#  'ASSIST OTHER AGENCY - EMERGENCY SERVICE'
#  'DIST - IP/JO - DV DIST - NO ASLT' '--ALARM-RESIDENTIAL PANIC OR DURESS'
#  'ALARM - COMM, SILENT/AUD BURG (INCL BANKS)' 'ESCAPE - PRISONER'
#  '--VICE - GAMBLING' '--DIRECTED PATROL ACTIVITY'
#  'TRAFFIC STOP - OFFICER INITIATED ONVIEW' '--AUTOMOBILES - ABANDONED CAR'
#  '--PREMISE CHECKS - REQUEST TO WATCH'
#  'PEACE-STANDBY TO ASSURE (NO COURT ORDR SVC)'
#  '--TRAFFIC - COMMUNITY TRAFFIC COMPLAINT (CTC)'
#  'MVC - HIT AND RUN (NON INJURY), INCLUDES IP/JO' 'DIST - DV - NO ASLT'
#  'LEWD -  (EXPOSING, FLASHING)' '--PREMISE CHECKS - BUSINESS CHECK'
#  'MVC - UNK INJURIES' '-ASSIGNED DUTY - FOOT BEAT (FROM ASSIGNED CAR)'
#  'BURN - RECKLESS BURNING' 'RAPE' 'PROWLER - IP/JO' 'NARCOTICS - FOUND'
#  'ORDER - VIOLATING DV COURT ORDER'
#  '--PREMISE CHECKS - HOMELESS ENCAMPMENT' 'PROPERTY - FOUND'
#  '--PROPERTY - MISSING PROPERTY'
#  '--ASSIST PUBLIC - 911 HANG UP, OPEN LINE'
#  'FIGHT - VERBAL/ORAL (NO WEAPONS)' 'OVERDOSE - DRUG RELATED CASUALTY'
#  'PROWLER' 'BIAS -RACIAL, POLITICAL, SEXUAL MOTIVATION'
#  'BIAS -IP/JO - RACIAL, POLITICAL, SEXUAL MOTIVATION'
#  'UNDERCOVER OPS, CAUTION (INCLUDES STAKEOUTS)'
#  'WARRANT PICKUP - FROM OTHER AGENCY'
#  'SEX IN PUBLIC PLACE/VIEW (INCL MASTURBATION)'
#  'NARCOTICS WARRANT SERVICE' 'DOWN - CHECK FOR DOWN PERSON'
#  'TRAFFIC - MOVING VIOLATION'
#  'NOISE - DIST, GENERAL (CONST, RESID, BALL PLAY)'
#  'DUI - DRIVING UNDER INFLUENCE']
#
#
# Call_Type
# ['-' '911' 'ONVIEW' 'TELEPHONE OTHER, NOT 911'
#  'ALARM CALL (NOT POLICE ALARM)' 'TEXT MESSAGE'
#  'SCHEDULED EVENT (RECURRING)']
#
#
# Officer_Squad
# ['WEST PCT 3RD W - MARY' 'SOUTH PCT 1ST W - R/S RELIEF'
#  'SOUTH PCT 1ST W - ROBERT' nan 'WEST PCT 2ND W - MARY BEATS'
#  'WEST PCT 2ND W - SPECIAL BEATS' 'TRAINING - FIELD TRAINING SQUAD'
#  'NORTH PCT 3RD W - LINCOLN' 'SOUTH PCT 3RD W - ROBERT'
#  'NORTH PCT 2ND W - NORA' 'NORTH PCT 2ND WATCH - B/N RELIEF'
#  'WEST PCT 3RD W - K/Q RELIEF' 'SOUTHWEST PCT 2ND W - WILLIAM'
#  'WEST PCT OPS - ACT NIGHT' 'WEST PCT 2ND W - KING'
#  'SOUTHWEST PCT 3RD W - WILLIAM' 'WEST PCT 2ND W - KING BEATS'
#  'SOUTH PCT OPS - NIGHT ACT' 'WEST PCT 2ND W - D/M RELIEF'
#  'NORTH PCT 1ST W - LINCOLN' 'NORTH PCT 1ST W - L/U RELIEF'
#  'WEST PCT 1ST W - KQ/DM RELIEF' 'SOUTH PCT 2ND W - OCEAN RELIEF'
#  'NORTH PCT OPS - ACT DAY' 'SOUTH PCT 3RD W - OCEAN'
#  'NORTH PCT 3RD W - NORA' 'WEST PCT 1ST W - DAVID/MARY'
#  'EAST PCT 2ND W - EDWARD' 'SOUTHWEST PCT 1ST W - FRANK'
#  'SOUTH PCT 1ST W - SAM' 'SOUTHWEST PCT 1ST W - WILLIAM'
#  'WEST PCT 2ND W - QUEEN' 'NORTH PCT 3RD W - JOHN'
#  'SOUTHWEST PCT 2ND WATCH - F/W RELIEF'
#  'EAST PCT 1ST W - GEORGE (CHARLIE)' 'WEST PCT 2ND W - DAVID BEATS'
#  'NORTH PCT 2ND W - L/U RELIEF' 'EAST PCT 3RD W - E/G RELIEF'
#  'EAST PCT 1ST W - EDWARD (CHARLIE)' 'SOUTH PCT 3RD W - SAM'
#  'SOUTH PCT 2ND W - SAM' 'NORTH PCT 3RD W - B/N RELIEF'
#  'NORTH PCT 1ST W - BOY (JOHN)' 'SOUTH PCT 3RD W - R/S RELIEF'
#  'NORTH PCT 3RD W - BOY' 'NORTH PCT 2ND W - UNION'
#  'WEST PCT 2ND W - DAVID' 'SOUTH PCT 3RD W - OCEAN RELIEF'
#  'SOUTH PCT 2ND W - OCEAN' 'NORTH PCT 1ST W - UNION'
#  'WEST PCT 3RD W - KING' 'SOUTHWEST PCT OPS - NIGHT ACT'
#  'NORTH PCT 2ND W - LINCOLN' 'EAST PCT 1ST W - E/G RELIEF (CHARLIE)'
#  'EAST PCT 3RD W - GEORGE' 'NORTH PCT 1ST W - NORA (JOHN)'
#  'EAST PCT 3RD W - EDWARD' 'NARC - PROACTIVE SQUAD C'
#  'NORTH PCT 2ND W - JOHN RELIEF' 'OPS BUREAU - SPECIAL ASSIGNMENTS'
#  'NORTH PCT 2ND WATCH - NORTH BEATS' 'EAST PCT 2ND W - CHARLIE'
#  'MAJOR CRIMES TASK FORCE' 'EAST PCT OPS - NIGHT ACT'
#  'NORTH PCT 1ST W - B/N RELIEF (JOHN)' 'SOUTHWEST PCT 2ND W - FRANK'
#  'TRAF - DUI SQUAD' 'NORTH PCT 3RD W - UNION'
#  'EAST PCT 2ND W - E/G RELIEF' 'SOUTHWEST PCT - 3RD WATCH - F/W RELIEF'
#  'NORTH PCT 2ND W - BOY' 'EAST PCT 2ND W - GEORGE'
#  'WEST PCT 3RD W - DAVID BEATS' 'SOUTHWEST PCT - 1ST WATCH - F/W RELIEF'
#  'SOUTH PCT OPS - DAY ACT' 'WEST PCT 2ND W - MARY'
#  'NORTH PCT 2ND W - JOHN' 'GANG SQUAD B'
#  'EAST PCT 3RD WATCH - CHARLIE RELIEF' 'SOUTH PCT 2ND W - ROBERT'
#  'EAST PCT 3RD W - CHARLIE' 'NORTH PCT 3RD W - L/U RELIEF'
#  'SOUTH PCT OPS - CPT' 'SOUTHWEST PCT 2ND W - SOUTHWEST BEATS'
#  'SOUTHWEST PCT 3RD W - FRANK' 'TRAINING - LEARNING MANAGEMENT SYSTEM'
#  'WEST PCT 1ST W - KING/QUEEN' 'WEST PCT OPS - CPT' 'SWAT - NIGHT SQUAD 2'
#  'CANINE - NIGHT SQUAD' 'SAU SQUAD A' 'NORTH PCT OPS - CPT'
#  'SOUTH PCT 2ND W - R/S RELIEF' 'CANINE - SQUAD C'
#  'WEST PCT 2ND W - K/Q RELIEF' 'SOUTH PCT 1ST W - OCEAN'
#  'EAST PCT 2ND W - CHARLIE RELIEF' 'EAST PCT 2ND W - BEATS'
#  'WEST PCT 3RD W - D/M RELIEF' 'WEST PCT 3RD W - DAVID' 'ROBBERY SQUAD B'
#  'SWAT - DAY SQUAD 2' 'NORTH PCT 3RD W - JOHN RELIEF' 'GANG SQUAD C'
#  'WEST PCT 3RD W - QUEEN' 'COMM - INTERNET AND TELEPHONE REPORTING (ITRU)'
#  'CRG - SQUAD 82D' 'CRG - SQUAD 81D' 'CRG - SQUAD 81A' 'CRG - SQUAD 82B'
#  'CRISIS RESPONSE SQUAD' 'CCI - MAJOR CRIMES TASK FORCE'
#  'DV SQUAD D - ORDER SERVICE' 'GANG SQUAD A' 'BURG/THEFT/JUV - SOUTH'
#  'EAST PCT OPS - CPT' 'WEST PCT OPS - SEA CTR' 'SWAT - DAY SQUAD 1'
#  'HARBOR - SQUAD A' 'SOUTH PCT 2ND W - SAM BEATS'
#  'EAST PCT 3RD W - EAST BEATS' 'CANINE - SQUAD A' 'TRAF - AM ENFORCEMENT'
#  'SOUTH PCT OPS - BURG/THEFT' 'HR - DEPARTMENT UNAVAILABLE PERSONNEL'
#  'AUTO THEFT' 'ROBBERY SQUAD A' 'COMMUNITY OUTREACH UNIT'
#  'SOUTHWEST PCT OPS - CPT'
#  'COMMUNITY OUTREACH - YOUTH VIOLENCE -SCHOOLS DETAIL'
#  'DV SQUAD A - INVESTIGATIONS'
#  'COMMUNITY OUTREACH - SPECIAL PROJECTS DETAIL'
#  'CRISIS INTERVENTION COORDINATION SQUAD'
#  'HR - HUMAN RESOURCES  - DEPT UNAVAIL PERSONNEL' 'BURG/THEFT/JUV - WEST'
#  'BURG/THEFT/JUV - NORTH' 'BURG/THEFT/JUV - EAST'
#  'WEST PCT OPS - MOUNTED PATROL' 'PAWN DETAIL' 'JOINT ENFORCEMENT TEAM'
#  'SOUTHWEST PCT OPS - DAY ACT' 'SOUTHWEST PCT OPS - BURG/THEFT'
#  'SWAT - NIGHT SQUAD 1' 'NORTH PCT OPS - BURG/THEFT' 'CRG - SQUAD 81C'
#  'CRG - SQUAD 81E' 'CRG - SQUAD 82E' 'CRG - SQUAD 82C' 'CRG - SQUAD 81B'
#  'CRG - SQUAD 82A' 'WEST PCT OPS - BURG/THEFT'
#  'HR - BLEA - ACADEMY RECRUITS' 'PUBLIC AFFAIRS SQUAD'
#  'TRAF - PM ENFORCEMENT' 'TRAF - COLLISION INVESTIGATION'
#  'CANINE - DAY SQUAD' 'JOINT ENFORCEMENT TEAM (JET)'
#  'COMMUNITY OUTREACH - YOUTH VIOLENCE-SCHOOLS DETAIL'
#  'EAST PCT OPS - BURG/THEFT' 'DV SQUAD C - ELDER ABUSE' 'SAU SQUAD B'
#  'NAVIGATION TEAM - SQUAD A' 'HARBOR - SQUAD D'
#  'TRAF - MOTORCYCLE UNIT - T4 SQUAD' 'RECORDS - DAY SHIFT'
#  'TRAINING - ADVANCED - SQUAD C' 'NORTH PCT 2ND W - PCT SUPPORT'
#  'TRAF - MOTORCYCLE UNIT - T2 SQUAD' 'VICE - GENERAL INVESTIGATIONS SQUAD'
#  'NAVIGATION TEAM - SQUAD B' 'ZOLD CRIME ANALYSIS UNIT - ANALYSTS']
#
#
# Arrest_Flag
# ['N' 'Y']
#
#
# Frisk_Flag
# ['N' '-' 'Y']
#
#
# Precinct
# ['-' 'East' 'South' 'North' 'West' 'Southwest' 'Unknown' 'SouthWest' 'OOJ'
#  'FK ERROR']
#
#
# Sector
# ['-' 'E     ' 'O     ' 'C     ' 'N     ' 'U     ' 'K     ' 'L     '
#  'G     ' 'F     ' 'R     ' 'W     ' 'J     ' 'M     ' 'D     ' 'S     '
#  'B     ' 'K' 'Q     ' '99    ' 'C' 'O' 'R' 'D' 'G' 'B' 'S' 'U' 'F' 'E'
#  'W' 'N' 'M' 'Q' 'J' 'L']
#
#
# Beat
# ['-' 'E2    ' 'O2    ' 'C3    ' 'N3    ' 'U1    ' 'K2    ' 'L2    '
#  'G2    ' 'U2    ' 'N2    ' 'F1    ' 'U3    ' 'F3    ' 'R1    ' 'W3    '
#  'J2    ' 'M3    ' 'L3    ' 'K1    ' 'D1    ' 'E1    ' 'C2    ' 'S1    '
#  'L1    ' 'S3    ' 'F2    ' 'O3    ' 'B3    ' 'G3    ' 'K3' 'Q3    '
#  'S2    ' 'Q1    ' 'R3    ' 'J3    ' 'R2    ' 'E3    ' 'C1    ' 'N1    '
#  'W1    ' 'M1    ' 'B2    ' 'W2    ' 'O1    ' 'M2    ' '99    ' 'D3    '
#  'B1    ' 'D2    ' 'K3    ' 'J1    ' 'K2' 'Q2    ' 'G1    ' 'C1' 'C2' 'O1'
#  'O2' 'R2' 'D3' 'C3' 'G2' 'B1' 'S3' 'U2' 'F1' 'E2' 'W2' 'K1' 'E3' 'S2'
#  'N1' 'U3' 'D1' 'B2' 'W1' 'O3' 'M3' 'Q1' 'J2' 'J3' 'F2' 'J1' 'Q3' 'W3'
#  'N3' 'U1' 'N2' 'G1' 'R1' 'S1' 'D2' 'M1' 'M2' 'F3' 'Q2' 'E1' 'L2' 'L1'
#  'R3' 'B3' 'L3' 'OOJ' 'G3' '99' 'S     ']

# %%
for col in terry_df.columns:
    print(col)
    print(terry_df[col].describe())
    print('\n')
# Out:
# Subject_Age_Group
# count       46315
# unique          7
# top       26_-_35
# freq        15403
# Name: Subject_Age_Group, dtype: object
#
#
# Subject_ID
# count               46,315.0
# mean    2,352,323,469.884638
# std     4,312,615,016.283802
# min                     -1.0
# 25%                     -1.0
# 50%                     -1.0
# 75%                     -1.0
# max         20,875,351,114.0
# Name: Subject_ID, dtype: float64
#
#
# GO_SC_Num
# count                46,315.0
# mean    20,175,328,470,588.99
# std      16,932,260,284.39549
# min      20,090,000,228,667.0
# 25%      20,160,000,150,431.0
# 50%      20,180,000,001,413.0
# 75%      20,190,000,177,188.0
# max      20,210,000,038,084.0
# Name: GO_SC_Num, dtype: float64
#
#
# Terry_Stop_ID
# count               46,315.0
# mean    3,271,846,989.807125
# std      5,831,562,145.01797
# min                 28,020.0
# 25%                178,567.5
# 50%                397,086.0
# 75%          8,225,744,617.5
# max         20,876,211,582.0
# Name: Terry_Stop_ID, dtype: float64
#
#
# Stop_Resolution
# count             46315
# unique                5
# top       Field Contact
# freq              18560
# Name: Stop_Resolution, dtype: object
#
#
# Weapon_Type
# count     46315
# unique       22
# top        None
# freq      32565
# Name: Weapon_Type, dtype: object
#
#
# Officer_ID
# count      46315
# unique      1201
# top       7456
# freq         417
# Name: Officer_ID, dtype: object
#
#
# Officer_YOB
# count              46,315.0
# mean    1,982.8173162042535
# std       9.367376922499403
# min                 1,900.0
# 25%                 1,978.0
# 50%                 1,985.0
# 75%                 1,990.0
# max                 1,998.0
# Name: Officer_YOB, dtype: float64
#
#
# Officer_Gender
# count     46315
# unique        3
# top           M
# freq      40991
# Name: Officer_Gender, dtype: object
#
#
# Officer_Race
# count     46315
# unique        9
# top       White
# freq      35083
# Name: Officer_Race, dtype: object
#
#
# Subject_Perceived_Race
# count     46315
# unique       10
# top       White
# freq      22601
# Name: Subject_Perceived_Race, dtype: object
#
#
# Subject_Perceived_Gender
# count     46315
# unique        6
# top        Male
# freq      36260
# Name: Subject_Perceived_Gender, dtype: object
#
#
# Reported_Date
# count                   46315
# unique                   2163
# top       2015-10-01T00:00:00
# freq                      101
# Name: Reported_Date, dtype: object
#
#
# Reported_Time
# count        46315
# unique       12218
# top       19:18:00
# freq            51
# Name: Reported_Time, dtype: object
#
#
# Initial_Call_Type
# count     46315
# unique      167
# top           -
# freq      13113
# Name: Initial_Call_Type, dtype: object
#
#
# Final_Call_Type
# count     46315
# unique      205
# top           -
# freq      13113
# Name: Final_Call_Type, dtype: object
#
#
# Call_Type
# count     46315
# unique        7
# top         911
# freq      20734
# Name: Call_Type, dtype: object
#
#
# Officer_Squad
# count                               45710
# unique                                170
# top       TRAINING - FIELD TRAINING SQUAD
# freq                                 4957
# Name: Officer_Squad, dtype: object
#
#
# Arrest_Flag
# count     46315
# unique        2
# top           N
# freq      43125
# Name: Arrest_Flag, dtype: object
#
#
# Frisk_Flag
# count     46315
# unique        3
# top           N
# freq      35488
# Name: Frisk_Flag, dtype: object
#
#
# Precinct
# count     46315
# unique       10
# top        West
# freq      11121
# Name: Precinct, dtype: object
#
#
# Sector
# count     46315
# unique       36
# top           -
# freq      10015
# Name: Sector, dtype: object
#
#
# Beat
# count     46315
# unique      107
# top           -
# freq       9956
# Name: Beat, dtype: object

# %% [markdown]
# #### Dealing with spaces in column values

# %% [markdown]
# ##### Remove spaces in Subject_Age_Group values

# %%
terry_df['Subject_Age_Group'].unique()
# Out:
# array(['-', '1 - 17', '18 - 25', '26 - 35', '36 - 45', '46 - 55',
#        '56 and Above'], dtype=object)

# %%
terry_df['Subject_Age_Group']
# Out:
# 0                   -
# 1                   -
# 2                   -
# 3                   -
# 4                   -
#              ...
# 46310    56 and Above
# 46311    56 and Above
# 46312    56 and Above
# 46313    56 and Above
# 46314    56 and Above
# Name: Subject_Age_Group, Length: 46315, dtype: object

# %%
terry_df['Subject_Age_Group'] = terry_df['Subject_Age_Group'].str.replace(' ', '_')
terry_df['Subject_Age_Group']
# Out:
# 0                   -
# 1                   -
# 2                   -
# 3                   -
# 4                   -
#              ...
# 46310    56_and_Above
# 46311    56_and_Above
# 46312    56_and_Above
# 46313    56_and_Above
# 46314    56_and_Above
# Name: Subject_Age_Group, Length: 46315, dtype: object

# %% [markdown]
# #### Deal with null / - values

# %%
# finding "-" values in dataframe

terry_df[terry_df == '-'].any()
# Out:
# Subject_Age_Group            True
# Subject_ID                  False
# GO_SC_Num                   False
# Terry_Stop_ID               False
# Stop_Resolution             False
# Weapon_Type                  True
# Officer_ID                   True
# Officer_YOB                 False
# Officer_Gender              False
# Officer_Race                False
# Subject_Perceived_Race       True
# Subject_Perceived_Gender     True
# Reported_Date               False
# Reported_Time               False
# Initial_Call_Type            True
# Final_Call_Type              True
# Call_Type                    True
# Officer_Squad               False
# Arrest_Flag                 False
# Frisk_Flag                   True
# Precinct                     True
# Sector                       True
# Beat                         True
# dtype: bool

# %%
terry_df['Subject_Age_Group'].value_counts()
# Out:
# 26_-_35         15403
# 36_-_45          9775
# 18_-_25          9336
# 46_-_55          5992
# 56_and_Above     2348
# 1_-_17           1961
# -                1500
# Name: Subject_Age_Group, dtype: int64

# %%
sns.countplot(y='Subject_Age_Group', data=terry_df )
# Out:
# <AxesSubplot:xlabel='count', ylabel='Subject_Age_Group'>

# %%
minors = terry_df[terry_df['Subject_Age_Group'] == '1_-_17']
minors.head()
# Out:
#      Subject_Age_Group  Subject_ID       GO_SC_Num  Terry_Stop_ID  \
# 932             1_-_17          -1  20150000002342          45058
# 1048            1_-_17          -1  20150000002342          45059
# 1187            1_-_17          -1  20150000002409          46007
# 1295            1_-_17          -1  20150000002409          46008
# 1504            1_-_17          -1  20140000342065         328166
#
#      Stop_Resolution Weapon_Type Officer_ID  Officer_YOB Officer_Gender  \
# 932    Field Contact        None     7597           1982              M
# 1048   Field Contact        None     7597           1982              M
# 1187   Field Contact        None     7430           1984              F
# 1295   Field Contact        None     7430           1984              F
# 1504          Arrest        None     7715           1992              M
#
#      Officer_Race            Subject_Perceived_Race Subject_Perceived_Gender  \
# 932         White                      Multi-Racial                     Male
# 1048        White                      Multi-Racial                     Male
# 1187        White                             White                     Male
# 1295        White                             White                   Female
# 1504        White  American Indian or Alaska Native                     Male
#
#             Reported_Date Reported_Time Initial_Call_Type Final_Call_Type  \
# 932   2015-05-19T00:00:00      19:09:00                 -               -
# 1048  2015-05-19T00:00:00      19:22:00                 -               -
# 1187  2015-05-23T00:00:00      01:55:00                 -               -
# 1295  2015-05-23T00:00:00      02:07:00                 -               -
# 1504  2015-09-13T00:00:00      00:31:00                 -               -
#
#      Call_Type                      Officer_Squad Arrest_Flag Frisk_Flag  \
# 932          -  NORTH PCT 2ND WATCH - NORTH BEATS           N          N
# 1048         -  NORTH PCT 2ND WATCH - NORTH BEATS           N          N
# 1187         -          NORTH PCT 3RD W - LINCOLN           N          N
# 1295         -          NORTH PCT 3RD W - LINCOLN           N          N
# 1504         -        EAST PCT 3RD W - E/G RELIEF           N          Y
#
#      Precinct  Sector    Beat
# 932         -       -       -
# 1048        -       -       -
# 1187        -       -       -
# 1295        -       -       -
# 1504     East  G       G1

# %%
terry_df.loc[(terry_df['Arrest_Flag'] == 'Yes') | (terry_df['Subject_Age_Group'] == '1_-_17')]
# Out:
#      Subject_Age_Group   Subject_ID       GO_SC_Num  Terry_Stop_ID  \
# 932             1_-_17           -1  20150000002342          45058
# 1048            1_-_17           -1  20150000002342          45059
# 1187            1_-_17           -1  20150000002409          46007
# 1295            1_-_17           -1  20150000002409          46008
# 1504            1_-_17           -1  20140000342065         328166
# ...                ...          ...             ...            ...
# 3460            1_-_17  19279791959  20210000005724    19279795571
# 3461            1_-_17  19823813824  20210000013504    19740209216
# 3462            1_-_17  20130088585  20210000026335    20326809061
# 3463            1_-_17  20296034267  20210000025433    20296092847
# 3464            1_-_17  20405789593  20210000030876    20405883620
#
#      Stop_Resolution Weapon_Type Officer_ID  Officer_YOB Officer_Gender  \
# 932    Field Contact        None     7597           1982              M
# 1048   Field Contact        None     7597           1982              M
# 1187   Field Contact        None     7430           1984              F
# 1295   Field Contact        None     7430           1984              F
# 1504          Arrest        None     7715           1992              M
# ...              ...         ...        ...          ...            ...
# 3460   Field Contact           -     8702           1979              M
# 3461   Field Contact           -     8343           1987              M
# 3462   Field Contact           -     8612           1984              F
# 3463   Field Contact           -     8582           1991              M
# 3464  Offense Report           -     8737           1995              M
#
#             Officer_Race            Subject_Perceived_Race  \
# 932                White                      Multi-Racial
# 1048               White                      Multi-Racial
# 1187               White                             White
# 1295               White                             White
# 1504               White  American Indian or Alaska Native
# ...                  ...                               ...
# 3460               White         Black or African American
# 3461  Hispanic or Latino         Black or African American
# 3462       Not Specified                                 -
# 3463               White         Black or African American
# 3464               White                           Unknown
#
#      Subject_Perceived_Gender        Reported_Date Reported_Time  \
# 932                      Male  2015-05-19T00:00:00      19:09:00
# 1048                     Male  2015-05-19T00:00:00      19:22:00
# 1187                     Male  2015-05-23T00:00:00      01:55:00
# 1295                   Female  2015-05-23T00:00:00      02:07:00
# 1504                     Male  2015-09-13T00:00:00      00:31:00
# ...                       ...                  ...           ...
# 3460                   Female  2021-01-08T00:00:00      00:48:43
# 3461                     Male  2021-01-17T00:00:00      00:31:08
# 3462                   Female  2021-02-01T00:00:00      00:08:08
# 3463                     Male  2021-01-30T00:00:00      22:30:29
# 3464                     Male  2021-02-06T00:00:00      00:32:10
#
#                                    Initial_Call_Type  \
# 932                                                -
# 1048                                               -
# 1187                                               -
# 1295                                               -
# 1504                                               -
# ...                                              ...
# 3460  WEAPN-IP/JO-GUN,DEADLY WPN (NO THRT/ASLT/DIST)
# 3461         TRAFFIC STOP - OFFICER INITIATED ONVIEW
# 3462           ASSIST OTHER AGENCY - ROUTINE SERVICE
# 3463                DISTURBANCE, MISCELLANEOUS/OTHER
# 3464     BURG - IP/JO - COMM BURG (INCLUDES SCHOOLS)
#
#                                 Final_Call_Type                 Call_Type  \
# 932                                           -                         -
# 1048                                          -                         -
# 1187                                          -                         -
# 1295                                          -                         -
# 1504                                          -                         -
# ...                                         ...                       ...
# 3460   --SUSPICIOUS CIRCUM. - SUSPICIOUS PERSON                       911
# 3461  --SUSPICIOUS CIRCUM. - SUSPICIOUS VEHICLE                    ONVIEW
# 3462      --ASSIST OTHER AGENCY - COUNTY AGENCY  TELEPHONE OTHER, NOT 911
# 3463                     --PROPERTY DEST (DAMG)                       911
# 3464                       --PROWLER - TRESPASS                       911
#
#                           Officer_Squad Arrest_Flag Frisk_Flag   Precinct  \
# 932   NORTH PCT 2ND WATCH - NORTH BEATS           N          N          -
# 1048  NORTH PCT 2ND WATCH - NORTH BEATS           N          N          -
# 1187          NORTH PCT 3RD W - LINCOLN           N          N          -
# 1295          NORTH PCT 3RD W - LINCOLN           N          N          -
# 1504        EAST PCT 3RD W - E/G RELIEF           N          Y       East
# ...                                 ...         ...        ...        ...
# 3460       NORTH PCT 3RD W - B/N RELIEF           N          N      North
# 3461                    CRG - SQUAD 82B           N          N      North
# 3462           SOUTH PCT 3RD W - ROBERT           N          Y          -
# 3463      SOUTHWEST PCT 3RD W - WILLIAM           N          N  SouthWest
# 3464           SOUTH PCT 3RD W - ROBERT           N          N       East
#
#       Sector    Beat
# 932        -       -
# 1048       -       -
# 1187       -       -
# 1295       -       -
# 1504  G       G1
# ...      ...     ...
# 3460       U      U1
# 3461       U      U1
# 3462       -       -
# 3463       W      W1
# 3464       G      G2
#
# [1961 rows x 23 columns]

# %%
# looking at weapon values
sns.countplot(y='Weapon_Type', data=terry_df )
# Out:
# <AxesSubplot:xlabel='count', ylabel='Weapon_Type'>

# %%
sns.catplot(y='Weapon_Type', col='Arrest_Flag', data=terry_df, 
           kind='count', height=5, aspect=.8)

# %%
#looking at arrests by group

terry_df.groupby(['Subject_Age_Group'])['Arrest_Flag'].count()
# Out:
# Subject_Age_Group
# -                1500
# 18_-_25          9336
# 1_-_17           1961
# 26_-_35         15403
# 36_-_45          9775
# 46_-_55          5992
# 56_and_Above     2348
# Name: Arrest_Flag, dtype: int64

# %%
terry_df.groupby(['Stop_Resolution'])['Arrest_Flag'].count()
# Out:
# Stop_Resolution
# Arrest                      11398
# Citation / Infraction         177
# Field Contact               18560
# Offense Report              15452
# Referred for Prosecution      728
# Name: Arrest_Flag, dtype: int64

# %%
terry_df.loc[(terry_df['Arrest_Flag'] == 'Y') | (terry_df['Stop_Resolution'] != 'Arrest')]
# Out:
#       Subject_Age_Group   Subject_ID       GO_SC_Num  Terry_Stop_ID  \
# 0                     -           -1  20150000002351          45252
# 1                     -           -1  20150000002363          45182
# 2                     -           -1  20150000002392          45365
# 3                     -           -1  20150000002451          46430
# 5                     -           -1  20150000001463          28806
# ...                 ...          ...             ...            ...
# 46310      56_and_Above  20160248170  20210000021921    20160361947
# 46311      56_and_Above  20171833316  20210000022390    20171881453
# 46312      56_and_Above  20356430687  20210000027381    20356441466
# 46313      56_and_Above  20370055391  20210000028500    20370213152
# 46314      56_and_Above  20414308762  20210000033131    20414094359
#
#       Stop_Resolution Weapon_Type Officer_ID  Officer_YOB Officer_Gender  \
# 0       Field Contact        None     7591           1985              M
# 1       Field Contact        None     7591           1985              M
# 2       Field Contact        None     7560           1986              M
# 3       Field Contact        None     7591           1985              M
# 5       Field Contact        None     5670           1965              M
# ...               ...         ...        ...          ...            ...
# 46310          Arrest           -     8776           1992              M
# 46311  Offense Report           -     8770           1995              F
# 46312   Field Contact           -     6123           1973              M
# 46313   Field Contact           -     8689           1987              M
# 46314   Field Contact           -     8728           1997              M
#
#              Officer_Race Subject_Perceived_Race Subject_Perceived_Gender  \
# 0      Hispanic or Latino                  Other                   Female
# 1      Hispanic or Latino                  White                     Male
# 2                   White                  White                   Female
# 3      Hispanic or Latino                      -                        -
# 5                   White                      -                        -
# ...                   ...                    ...                      ...
# 46310   Two or More Races                  White                     Male
# 46311               White                Unknown                   Female
# 46312               White                  White                   Female
# 46313               White                  White                   Female
# 46314               White                  White                     Male
#
#              Reported_Date Reported_Time  \
# 0      2015-05-20T00:00:00      21:39:00
# 1      2015-05-20T00:00:00      22:40:00
# 2      2015-05-22T00:00:00      07:39:00
# 3      2015-05-25T00:00:00      01:06:00
# 5      2015-03-19T00:00:00      07:59:00
# ...                    ...           ...
# 46310  2021-01-26T00:00:00      23:32:26
# 46311  2021-01-27T00:00:00      13:47:49
# 46312  2021-02-02T00:00:00      10:35:06
# 46313  2021-02-03T00:00:00      14:30:26
# 46314  2021-02-08T00:00:00      16:03:34
#
#                                    Initial_Call_Type  \
# 0                                                  -
# 1                                                  -
# 2                                                  -
# 3                                                  -
# 5                                                  -
# ...                                              ...
# 46310  THREATS (INCLS IN-PERSON/BY PHONE/IN WRITING)
# 46311      ASLT - WITH OR W/O WEAPONS (NO SHOOTINGS)
# 46312     MVC - WITH INJURIES (INCLUDES HIT AND RUN)
# 46313     BURG - IP/JO - RES (INCL UNOCC STRUCTURES)
# 46314                               SHOPLIFT - THEFT
#
#                               Final_Call_Type Call_Type  \
# 0                                           -         -
# 1                                           -         -
# 2                                           -         -
# 3                                           -         -
# 5                                           -         -
# ...                                       ...       ...
# 46310        --ASSAULTS - HARASSMENT, THREATS       911
# 46311                       --ASSAULTS, OTHER       911
# 46312  --TRAFFIC - MV COLLISION INVESTIGATION       911
# 46313                    --PROWLER - TRESPASS       911
# 46314                      --THEFT - SHOPLIFT       911
#
#                                Officer_Squad Arrest_Flag Frisk_Flag Precinct  \
# 0                      WEST PCT 3RD W - MARY           N          N        -
# 1                      WEST PCT 3RD W - MARY           N          N        -
# 2               SOUTH PCT 1ST W - R/S RELIEF           N          N     East
# 3                      WEST PCT 3RD W - MARY           N          N        -
# 5                                        NaN           N          N        -
# ...                                      ...         ...        ...      ...
# 46310        TRAINING - FIELD TRAINING SQUAD           Y          Y     West
# 46311        TRAINING - FIELD TRAINING SQUAD           N          N     West
# 46312         TRAF - COLLISION INVESTIGATION           N          N     West
# 46313                  WEST PCT 2ND W - KING           N          N     West
# 46314  HR - DEPARTMENT UNAVAILABLE PERSONNEL           N          N     West
#
#        Sector    Beat
# 0           -       -
# 1           -       -
# 2      E       E2
# 3           -       -
# 5           -       -
# ...       ...     ...
# 46310       Q      Q3
# 46311       D      D3
# 46312       M      M2
# 46313       Q      Q2
# 46314       M      M3
#
# [38105 rows x 23 columns]

# %% [markdown]
# ## [ ] Columns to look at for encoding
#
# - Arrest_Flag *** binary, implicated in Stop_Resolution
# - Officer_YOB *** change to age?
#
# - Subject_Age_Group
# - Stop_Resolution
# - Weapon_Type ***
# - Officer_ID
# - Officer_Gender
# - Officer_Race
# - Subject_Perceived_Race
# - Subject_Perceived_Gender
# - Reported_Date
# - Reported_Time
# - Initial_Call_Type
# - Final_Call_Type
# - Call_Type
# - Officer_Squad
# - Frisk_Flag
# - Precinct
# - Sector
# - Beat
